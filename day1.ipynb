# %%
# !git config --global user.email "me@example.com"
# !git config --global user.name "nervuzz"
# !git commit -m 'Day 1'
# !git pull
# !git add .
# !git status
# !git push

# %%
cd "drive/My Drive/Colab Notebooks/data_workshop_tsr/"
# Out:
# /content/drive/My Drive/Colab Notebooks/data_workshop_tsr

# %%
import pandas as pd

# %%
train = pd.read_pickle('data/train.p')
train.keys()
# Out:
# dict_keys(['coords', 'labels', 'features', 'sizes'])

# %%
X_train, y_train = train['features'], train['labels']
X_train.shape, y_train.shape
# Out:
# ((34799, 32, 32, 3), (34799,))

# %%
pd.read_csv('data/signnames.csv').sample(5)
# Out:
#      a                                         b
# 6    6               End of speed limit (80km/h)
# 16  16  Vehicles over 3.5 metric tons prohibited
# 40  40                      Roundabout mandatory
# 38  38                                Keep right
# 19  19               Dangerous curve to the left

# %%
# !git push
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.76 KiB | 600.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/nervuzz/data_workshop_tsr.git
#    ae1dfec..2e44eb3  master -> master
